# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def rate_hw(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_attached and\
             course in self.courses_in_progress and str(grade).isnumeric() and 0 < int(grade) < 11:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def hv_grade(self):
        sum_grade = 0
        len_grade = 0
        for i in best_student.grades.values() :
            sum_grade += sum(i)
            len_grade += len(i)
        if len_grade:
            return round(sum_grade / len_grade, 1)
        
        else:
            return 'Оценок нет'

    def __lt__(self, other):
        if not isinstance(other, Student):
            print('Not a Lecturer')
            return
        return self.finished_courses < other.finished_courses

    def __str__(self):
        progress = self.courses_in_progress
        in_progress = ", ".join(progress)
        best_student = f'Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашнее задание: {self.hv_grade()}\nКурсы в процессе изучения: {in_progress}\
            \nЗавершенные курсы: Введение в программирование'
        return best_student

class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []
        
        
class Lecturer(Mentor):
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.grades = {}
        self.courses_attached = []

    def av_grade(self):
        sum_grade = 0
        x_grade = 0
        for grade in self.grades.values():
            sum_grade += sum(grade)
            x_grade += len(grade)
        if x_grade:
            return round(sum_grade / x_grade, 1)
        
        else:
            return 'Оценок нет'

    def __lt__(self, other):
        if not isinstance(other, Lecturer):
            print('Not a Lecturer')
            return
        return self.courses_attached > other.courses_attached

    def __str__(self) -> str:
        return f'Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {self.av_grade()}'

class Reviewer(Mentor):

    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress and\
            str(grade).isnumeric() and 0 < int(grade) < 11:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'
    def hv_grade(self):
        sum_grade = 0
        len_grade = 0
        for i in best_student.grades.values() :
            sum_grade += sum(i)
            len_grade += len(i)
        if len_grade:
            return sum_grade / len_grade
        else:
            return 'Оценок нет'

    def __str__(self) -> str:
        return f'Имя: {self.name}\nФамилия: {self.surname}'

def get_hv(students, cource):    
    sum_hv = 0
    count = 0
    for student in students:
        if cource in cool_student.grades:
            sum_hv += sum(cool_student.grades[cource])
            count += len(cool_student.grades[cource])
            return round(sum_hv/count ,2)   
        else:
            return 'Оценок нет'

def get_av(lecturers, cource):    
    sum_hv = 0
    count = 0
    for lecturer in lecturers:
        if cource in  some_lecturer.grades:
            sum_hv += sum(some_lecturer.grades[cource])
            count += len(some_lecturer.grades[cource])
            return round(sum_hv/count ,2)   
        else:
            return 'Оценок нет'

some_lecturer = Lecturer('Mariya', 'Ivanova')
cool_lecturer = Lecturer('Svetlana', 'Rodionova')
some_lecturer.courses_attached += ['Python', 'Git']
cool_lecturer.courses_attached += ['Python', ' Git', 'Java']

lecturers = [some_lecturer, cool_lecturer]

some_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer.courses_attached += ['Python', 'Git']

best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_student = Student('Olesya', 'Petrova','your_gender')
cool_student.courses_in_progress += ['Python', 'Git']
cool_student.grades['Git'] = [10, 10, 7, 10, 10]
cool_student.grades['Python'] = [10, 7]

cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 10)

best_student.courses_in_progress += ['Python', 'Git']
best_student.grades['Git'] = [10, 10, 7, 10, 10]
best_student.grades['Python'] = [10, 5]

students = [cool_student, best_student]

best_student.rate_hw(some_lecturer, 'Python', 9)
best_student.rate_hw(cool_lecturer, 'Git', 7)
best_student.rate_hw(some_lecturer, 'Git', 5)
best_student.rate_hw(some_lecturer, 'Git', 6)

print(best_student.grades)
print(some_lecturer.grades)
print(some_reviewer)
print(some_lecturer)
print(best_student)
print(some_lecturer < cool_lecturer)
print(best_student > cool_student)
print(get_hv(students, 'Git'))
print(get_av(lecturers, 'Git'))
# Out:
# {'Git': [10, 10, 7, 10, 10], 'Python': [10, 5]}
# {'Python': [9], 'Git': [5, 6]}
# Имя: Some
# Фамилия: Buddy
# Имя: Mariya
# Фамилия: Ivanova
# Средняя оценка за лекции: 6.7
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашнее задание: 8.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# True
# False
# 9.4
# 5.5
